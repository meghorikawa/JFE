# %%
# import statements
import pandas as pd
import numpy as np
from interpret.glassbox import ExplainableBoostingClassifier
from interpret import show
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import os

# %% [markdown]
# # --- 5 Fold Cross Validation ---

# %%
#load data

file_path = os.path.join(os.getcwd(), 'training_data.csv')

#file_path = 'Users/megu/Documents/Tübingen Universität/Thesis/FeatureExtractor/src/training_data.csv'

df = pd.read_csv(file_path, index_col=0)

df = pd.read_csv(file_path, index_col=0)

#remove participant and text columns
df = df.drop(columns=['participant', 'text_name','JCATscore', 'loc', 'lang', 'age', 'gender']) # remove identifiers.

#remove native speaker rows
df=df[df['JLPT'] != 'NS']

#replace empty fields with 0
df=df.fillna(0)

#ensure categorical variables are recognized as such
categorical_columns = ['JLPT']

for col in categorical_columns:
    df[col] = df[col].astype('category')


X = df.drop(columns=['JLPT']) # feature columns (everything but JLPT column)
y = df['JLPT'].astype(str)

features_names = X.columns.tolist() 

# set the splits
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Set up cross validation
all_true=[]
all_predictions = []
all_indices = []
pre_counts_total = Counter()
post_counts_total= Counter()

for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
  print(f"\n Fold: {fold}")

  # split data
  x_train, x_test = X.iloc[train_index], X.iloc[test_index]
  y_train, y_test = y.iloc[train_index], y.iloc[test_index]
  pre_counts_total.update(y_train.value_counts().to_dict()) # update counts pre-sampling

  #Oversample within the training set
  ros = RandomOverSampler(random_state=42)
  x_train_resampled, y_train_resampled = ros.fit_resample(x_train, y_train)

  #convert resampled target to regular series
  y_train_resampled = pd.Series(y_train_resampled).astype(str)
  post_counts_total.update(y_train_resampled.value_counts().to_dict()) # update counts post-sampling

  #Train EBM
  ebm_fold = ExplainableBoostingClassifier(
      interactions=0, # no interactions
      random_state=42,
      n_jobs=1,
      )
  
  ebm_fold.fit(x_train_resampled, y_train_resampled)

  #Predict and evaluate
  y_pred = ebm_fold.predict(x_test)

  all_true.append(y_test)
  all_predictions.append(y_pred)
  all_indices.append(x_test.index)



  print(classification_report(y_test,y_pred))


print('finished training')
print('\n')
print('Total JLPT distribution BEFORE oversampling (across all folds)')
print('\n')
print(dict(pre_counts_total))
print('\n')
print('Total JLPT distribution AFTER oversampling (across all folds)')
print('n')
print(dict(post_counts_total))
######################################################
#  Model performace evaluation
######################################################
# Aggregate OOF results
y_true_all = pd.concat(all_true)
y_pred_all = np.concatenate(all_predictions)
indices_all = np.concatenate(all_indices)

# sort by the original order
order = np.argsort(indices_all)
y_true_all = y_true_all.iloc[order]
y_pred_all = y_pred_all[order]


JLPT_levels= ['N5','N4','N3','N2','N1']

cm= confusion_matrix(y_true_all, y_pred_all, labels=JLPT_levels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=JLPT_levels,
            yticklabels=JLPT_levels)
plt.xlabel('Predicted JLPT')
plt.ylabel('True JLPT')
plt.title('Confusion Matrix JLPT Level Prediction')
plt.show()


print('\n Overall Classification Report (All Folds Combined):')
print(classification_report(y_true_all, y_pred_all, labels=JLPT_levels))

####################################
# Per JLPT lvl Metrics
###################################

print("\n Per JLPT Level Metrics")
for level in JLPT_levels:
  mask = y_true_all == level
  y_true_subset = y_true_all[mask]
  y_pred_subset = y_pred_all[mask]
  accuracy = accuracy_score(y_true_subset, y_pred_subset)
  precision = precision_score(y_true_subset, y_pred_subset, average='weighted')
  recall = recall_score(y_true_subset, y_pred_subset, average='weighted')
  f1 = f1_score(y_true_subset, y_pred_subset, average='weighted')
  print(f"{level}: Accuracy = {accuracy} Precision = {precision} Recall = {recall} F1=f1")



######################################
# Final Model
######################################
ebm_final = ExplainableBoostingClassifier(
    interactions=0, # no interactions
    random_state=42,
    n_jobs=1,
    max_bins=256,
    max_leaves = 3,
    )
  
ebm_final.fit(X, y)

ebm_global = ebm_final.explain_global()
show(ebm_global)
# Out:
#  Fold: 0
#               precision    recall  f1-score   support
#
#           N1       0.22      0.24      0.23        45
#           N2       0.39      0.40      0.40       163
#           N3       0.42      0.41      0.41       269
#           N4       0.47      0.42      0.44       286
#           N5       0.47      0.55      0.50       147
#
#     accuracy                           0.43       910
#    macro avg       0.39      0.41      0.40       910
# weighted avg       0.43      0.43      0.43       910
#
#
#  Fold: 1
#               precision    recall  f1-score   support
#
#           N1       0.14      0.16      0.15        45
#           N2       0.32      0.37      0.34       163
#           N3       0.35      0.32      0.33       269
#           N4       0.41      0.38      0.39       286
#           N5       0.39      0.40      0.40       147
#
#     accuracy                           0.35       910
#    macro avg       0.32      0.33      0.32       910
# weighted avg       0.36      0.35      0.36       910
#
#
#  Fold: 2
#               precision    recall  f1-score   support
#
#           N1       0.21      0.24      0.22        45
#           N2       0.31      0.35      0.33       163
#           N3       0.36      0.34      0.35       268
#           N4       0.46      0.39      0.42       287
#           N5       0.46      0.54      0.50       147
#
#     accuracy                           0.39       910
#    macro avg       0.36      0.37      0.36       910
# weighted avg       0.39      0.39      0.39       910
#
#
#  Fold: 3
#               precision    recall  f1-score   support
#
#           N1       0.10      0.14      0.11        44
#           N2       0.32      0.35      0.33       164
#           N3       0.35      0.30      0.33       268
#           N4       0.40      0.40      0.40       286
#           N5       0.49      0.52      0.51       147
#
#     accuracy                           0.37       909
#    macro avg       0.33      0.34      0.34       909
# weighted avg       0.37      0.37      0.37       909
#
#
#  Fold: 4
#               precision    recall  f1-score   support
#
#           N1       0.13      0.16      0.14        45
#           N2       0.36      0.44      0.39       163
#           N3       0.39      0.33      0.36       268
#           N4       0.40      0.36      0.38       286
#           N5       0.45      0.52      0.48       147
#
#     accuracy                           0.38       909
#    macro avg       0.34      0.36      0.35       909
# weighted avg       0.38      0.38      0.38       909
#
# finished training
#
#
# Total JLPT distribution BEFORE oversampling (across all folds)
#
#
# {'N4': 5724, 'N3': 5368, 'N2': 3264, 'N5': 2940, 'N1': 896}
#
#
# Total JLPT distribution AFTER oversampling (across all folds)
# n
# {'N5': 5724, 'N3': 5724, 'N4': 5724, 'N2': 5724, 'N1': 5724}
#  Overall Classification Report (All Folds Combined):
#               precision    recall  f1-score   support
#
#           N5       0.45      0.51      0.48       735
#           N4       0.43      0.39      0.41      1431
#           N3       0.38      0.34      0.36      1342
#           N2       0.34      0.38      0.36       816
#           N1       0.15      0.19      0.17       224
#
#     accuracy                           0.38      4548
#    macro avg       0.35      0.36      0.35      4548
# weighted avg       0.39      0.38      0.38      4548
#
#
#  Per JLPT Level Metrics
# N5: Accuracy = 0.508843537414966 Precision = 1.0 Recall = 0.508843537414966 F1=f1
# N4: Accuracy = 0.389937106918239 Precision = 1.0 Recall = 0.389937106918239 F1=f1
# N3: Accuracy = 0.3405365126676602 Precision = 1.0 Recall = 0.3405365126676602 F1=f1
# N2: Accuracy = 0.38235294117647056 Precision = 1.0 Recall = 0.38235294117647056 F1=f1
# N1: Accuracy = 0.1875 Precision = 1.0 Recall = 0.1875 F1=f1
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# <!-- http://127.0.0.1:7001/12948109792/ -->
# <iframe src="http://127.0.0.1:7001/12948109792/" width=100% height=800 frameBorder="0"></iframe>

# %%
features_importance = ebm_global.data()

features_names = features_importance['names']
feature_importances = features_importance['scores']

sorted_features = sorted(zip(features_names, feature_importances), key=lambda x: x[1], reverse=True)

i=1
print(f'Top features rank')
for feature, importance in sorted_features:
    print(f"{i}. {feature}: {importance}")
    i+=1
# Out:
# Top features rank
# 1. Coordinate Clauses per sentence: 0.06150714808171355
# 2. Coordinate Clauses per clause: 0.06068824066234101
# 3. JLPT_Vocab_percent_N2: 0.05429376943212962
# 4. MHD: 0.0525333771807535
# 5. SCfreq: 0.050281970076648065
# 6. mci_5_surface: 0.04466900661502047
# 7. mci_10_surface: 0.043070862529754915
# 8. Avg Clause per Sent: 0.03623237502125395
# 9. JLPT_Vocab_percent_N4: 0.03583354052601373
# 10. LFP_OOV_percent: 0.03417828198993205
# 11. Avg Sent Length: 0.03219610903691309
# 12. CF_ukemi_N4_ratio: 0.03126223860303747
# 13. mci_10_inflection: 0.030292267341243982
# 14. MDD: 0.028865700725363912
# 15. JRMA_function_MATTR: 0.02859698967395621
# 16. JRMA_all_MATTR: 0.028462833468423064
# 17. adverb_density: 0.027861075987279264
# 18. adjective_density: 0.02784336896967561
# 19. JLPT_Vocab_N2: 0.02748448237074789
# 20. verb_density: 0.02559311571549184
# 21. LFP_3k_percent: 0.02545309887572069
# 22. JRMA_aux_chains: 0.025180621424552945
# 23. Subordinate Clauses per clause: 0.024741992832639205
# 24. LFP_4k_percent: 0.024021556095892963
# 25. LFP_9k_percent: 0.023467249015147632
# 26. JRMA_content_MTLD: 0.023109229221183386
# 27. LFP_6k_percent: 0.023014182979255164
# 28. JLPT_Vocab_percent_N5: 0.022783369517026454
# 29. CF_tekuru_N4_ratio: 0.022612454082800208
# 30. JLPT_Vocab_percent_N3: 0.02216269755750527
# 31. LFP_1k_percent: 0.021355355512677626
# 32. noun_density: 0.021214591872729633
# 33. JRMA_content_MATTR: 0.020953490174211113
# 34. JRMA_all_MTLD: 0.02054815715675381
# 35. JLPT_Vocab_percent_N1: 0.020473104412723174
# 36. MTLD_lemma: 0.020278996544812262
# 37. MTLD_surface: 0.019643636228142535
# 38. mci_5_inflection: 0.01903934312186635
# 39. LFP_7k_percent: 0.018185810630424838
# 40. CTTR: 0.017932091897093303
# 41. Avg Clause Length: 0.017571326083718843
# 42. JRMA_function_MTLD: 0.017160689868880072
# 43. Avg NP length: 0.01605753771687239
# 44. CF_saseru_N4_ratio: 0.015906397320456643
# 45. LFP_OOV_count: 0.01569149661814406
# 46. CF_toomou_N4_ratio: 0.015411918712733208
# 47. LFP_2k_percent: 0.015057894113281591
# 48. CCfreq: 0.014675743170880887
# 49. LFP_5k_percent: 0.014325431687252164
# 50. CF_saseru_N4_total: 0.013814928387995092
# 51. LFP_total_tokens: 0.013650962783384547
# 52. JLPT_Vocab_N4: 0.013611713114553323
# 53. CF_tsumori_N5_ratio: 0.013356655543628825
# 54. LFP_3k_count: 0.01332368180340223
# 55. CF_zuni_N3_total: 0.013134780351151475
# 56. JLPT_Vocab_N5: 0.013061788720780523
# 57. CF_tekuru_N4_total: 0.01297805734547482
# 58. CF_tara_N4_ratio: 0.012855572940248621
# 59. CF_tai_N5_ratio: 0.012707955900289112
# 60. CF_tsumori_N5_total: 0.012585400500429268
# 61. LFP_9k_count: 0.012547067517999083
# 62. LFP_6k_count: 0.012463705224541455
# 63. CF_total_N5: 0.012229446088818726
# 64. LFP_1k_count: 0.011938779497081138
# 65. Text Length: 0.011400873867257457
# 66. JLPT_Vocab_N1: 0.011372280578867333
# 67. Avg VP length: 0.011076144276636618
# 68. LFP_4k_count: 0.011041198053595366
# 69. CF_zuni_N3_ratio: 0.01102253156093988
# 70. CF_total_N4: 0.010927976369878115
# 71. LFP_2k_count: 0.010784466892699657
# 72. LFP_5k_count: 0.010783034964550567
# 73. Subordinate Clauses per Coordinate Clauses: 0.010259920818084219
# 74. LFP_7k_count: 0.010115360690594289
# 75. Subordinate Clauses per sentence: 0.010083370245237687
# 76. JLPT_Vocab_N3: 0.010039978994363197
# 77. CF_ukemi_N4_total: 0.009643191434162776
# 78. CF_hougaii_N5_ratio: 0.009351855103333405
# 79. CF_uchini_N3_total: 0.008734973219999952
# 80. CF_tara_N4_total: 0.008712062249776446
# 81. LFP_8k_percent: 0.008546019130204242
# 82. CF_hougaii_N5_total: 0.007878908174117594
# 83. CF_toomou_N4_total: 0.007583304759933407
# 84. CF_tai_N5_total: 0.007434154132003967
# 85. CF_total_N3: 0.007421550848488843
# 86. CF_toiu_N3_ratio: 0.007144851991801394
# 87. CF_uchini_N3_ratio: 0.007103463280239441
# 88. CF_total_N2: 0.006826881279695727
# 89. CF_temiru_N4_ratio: 0.006701900864286564
# 90. CF_tekudasai_N5_ratio: 0.006608760423982103
# 91. CF_burini_N2_total: 0.0065325792266560795
# 92. LFP_10k_percent: 0.006181343798358421
# 93. CF_ichiban_N5_ratio: 0.0059526351493430895
# 94. CF_temiru_N4_total: 0.005647607138270839
# 95. CF_tekudasai_N5_total: 0.005568736490901888
# 96. CF_youni_N4_ratio: 0.005163357192573189
# 97. CF_burini_N2_ratio: 0.00514291929455344
# 98. CF_gozaimasu_N4_total: 0.004871573414206807
# 99. CF_toiu_N3_total: 0.004804506169505024
# 100. CF_tari_N5_ratio: 0.004804249701802555
# 101. CF_okagede_N3_total: 0.004763069299760651
# 102. CF_amari_N3_ratio: 0.004742805507534316
# 103. LFP_8k_count: 0.004694146840787795
# 104. CF_tokoro_bakari_N4_ratio: 0.004656135148702695
# 105. CF_amari_N3_total: 0.004441057626139295
# 106. CF_dakedenaku_N3_total: 0.004307464872987078
# 107. CF_ichiban_N5_total: 0.004265109714336268
# 108. CF_youni_N4_total: 0.0042308123160708574
# 109. CF_tekureru_N4_ratio: 0.004162325175445361
# 110. CF_teitadakimasen_N4_ratio: 0.004068536761090168
# 111. CF_kotogaaru_N4_total: 0.004036823209102564
# 112. LFP_10k_count: 0.004035019418048702
# 113. CF_gozaimasu_N4_ratio: 0.003989883291995589
# 114. CF_ippou_N2_total: 0.0039831856073068665
# 115. CF_tekureru_N4_total: 0.0038962187237622688
# 116. CF_tokoro_bakari_N4_total: 0.003816286517344749
# 117. CF_bekida_N3_total: 0.003732798673163137
# 118. CF_teitadakimasen_N4_total: 0.003570451152335639
# 119. CF_sonoue_N2_total: 0.0035573534919641062
# 120. CF_tari_N5_total: 0.0034770518265418173
# 121. CF_kamoshirenai_N4_ratio: 0.003316177449171489
# 122. CF_tabini_N3_ratio: 0.0033114900307711515
# 123. CF_tashikani_N3_total: 0.003287783522846524
# 124. CF_ikurademo_N3_total: 0.003215455699269195
# 125. CF_okagede_N3_ratio: 0.003199336057628323
# 126. CF_tashikani_N3_ratio: 0.0031676013565272877
# 127. CF_ijyou_N4_total: 0.0031142761403261036
# 128. CF_sugiru_N5_total: 0.003057204355883612
# 129. CF_ijyou_N4_ratio: 0.0030497973281293127
# 130. CF_yasui_N4_total: 0.0030324599296294203
# 131. CF_kotogaaru_N4_ratio: 0.003003375209796457
# 132. CF_nasaru_N4_total: 0.002892512848756538
# 133. CF_ippou_N2_ratio: 0.0028619768498541493
# 134. CF_sugiru_N5_ratio: 0.0027673511875977766
# 135. CF_nakutehaikenai_N5_total: 0.002766114520234672
# 136. CF_eru_N2_total: 0.002736682695362342
# 137. CF_temorau_N4_total: 0.0027330221384195908
# 138. CF_teshimau_N4_total: 0.002714540125295236
# 139. CF_bekida_N3_ratio: 0.002708420931856811
# 140. CF_sonoue_N2_ratio: 0.002695552640111292
# 141. CF_hodonai_N3_total: 0.0026843555091285378
# 142. CF_yasui_N4_ratio: 0.0026672045681104886
# 143. CF_dakedo_N3_total: 0.0026505342456746056
# 144. CF_ikurademo_N3_ratio: 0.002648984890679722
# 145. CF_kurai_N5_ratio: 0.0026286979136932744
# 146. CF_kamoshirenai_N4_total: 0.0025811364585373343
# 147. CF_mottomo_N2_total: 0.002579710403750538
# 148. CF_seide_N3_ratio: 0.002531886284191959
# 149. CF_tabini_N3_total: 0.0025248703422983266
# 150. CF_total_N1: 0.002464244201469871
# 151. CF_hodo_N3_total: 0.002454138205748542
# 152. CF_hodo_N3_ratio: 0.0024476158704215124
# 153. CF_dakedo_N3_ratio: 0.002424912754910907
# 154. CF_nikuraberu_N3_total: 0.0024233793659922415
# 155. CF_nagaramo_N3_total: 0.0024112930805474287
# 156. CF_totomoni_N3_total: 0.002372448718432996
# 157. CF_kurai_N5_total: 0.0023671557657829008
# 158. CF_mitaini_N4_total: 0.0023620519747018253
# 159. CF_koso_N3_total: 0.002335253629904908
# 160. CF_yara_N2_total: 0.002294779182209821
# 161. CF_shikanai_N3_ratio: 0.002287484394887142
# 162. CF_sarani_N3_ratio: 0.0022334781552753786
# 163. CF_nasaru_N4_ratio: 0.002224837102972688
# 164. CF_dakedenaku_N3_ratio: 0.0022137204438746664
# 165. CF_temorau_N4_ratio: 0.0021961295006796156
# 166. CF_monodakara_N2_total: 0.0021879231565567724
# 167. CF_teshimau_N4_ratio: 0.0021684251758044507
# 168. CF_gasuru_N4_ratio: 0.0021247358615119677
# 169. CF_sae_N3_total: 0.0021053081914303544
# 170. CF_yori_N4_total: 0.0020867794818722122
# 171. CF_seide_N3_total: 0.0020745407586668417
# 172. CF_mitai_N4_total: 0.00202870634991366
# 173. CF_tsutsuaru_N2_total: 0.0019930371545293975
# 174. CF_nikui_N4_total: 0.0019905831225066044
# 175. CF_yori_N4_ratio: 0.00197352392267356
# 176. CF_mitai_N4_ratio: 0.001971727112826061
# 177. CF_shikanai_N4_total: 0.0019305968014067098
# 178. CF_eru_N2_ratio: 0.001918945135496485
# 179. CF_nakutehaikenai_N5_ratio: 0.0019032076441419582
# 180. CF_mottomo_N2_ratio: 0.0018306726952128543
# 181. CF_tsumari_N3_total: 0.0018302975118253888
# 182. CF_yara_N2_ratio: 0.0018098199118737044
# 183. CF_nikuraberu_N3_ratio: 0.0018068347117596141
# 184. CF_hodonai_N3_ratio: 0.0017771517825756445
# 185. CF_sae_N3_ratio: 0.0017370387334160482
# 186. CF_totomoni_N3_ratio: 0.001735861831441467
# 187. CF_nasai_N4_total: 0.0017125533136037644
# 188. CF_sarani_N3_total: 0.0016974239979911324
# 189. CF_gasuru_N4_total: 0.0016911365734792122
# 190. CF_shikanai_N3_total: 0.0016770396704625893
# 191. CF_ppoi_N3_total: 0.0016625963557773996
# 192. CF_monodakara_N2_ratio: 0.0016567342033667976
# 193. CF_nagaramo_N3_ratio: 0.0016366334570533853
# 194. CF_mitaini_N4_ratio: 0.0015784143050370809
# 195. CF_koso_N3_ratio: 0.0015502862487438303
# 196. CF_moshikashitara_N3_total: 0.0015342828585238775
# 197. CF_kanousei_N1_total: 0.0015229389054557667
# 198. CF_tsumari_N3_ratio: 0.0014564281201736684
# 199. CF_soretomo_N3_total: 0.001445163468946708
# 200. CF_shikanai_N4_ratio: 0.0014144037829799635
# 201. CF_nikui_N4_ratio: 0.0014089031217077135
# 202. CF_shidai_N2_total: 0.0014088034516525937
# 203. CF_nimokakawarazu_N2_total: 0.0013949520140053582
# 204. CF_tsumoride_N3_total: 0.0013357449690318312
# 205. CF_shikamo_N2_total: 0.0013050674480749442
# 206. CF_osoregaru_N2_total: 0.0012809142820578666
# 207. CF_monono_N2_total: 0.001262095361384917
# 208. CF_nasai_N4_ratio: 0.0012141733296100329
# 209. CF_tsutsuaru_N2_ratio: 0.0012091437686160718
# 210. CF_osoregaru_N2_ratio: 0.0011869666257495683
# 211. CF_tokangaerareru_N2_ratio: 0.0011783888107511518
# 212. CF_tokangaerareru_N2_total: 0.0011487145796328904
# 213. CF_sorenishitemo_N2_total: 0.0011437688076314562
# 214. CF_nao_N2_total: 0.0011410861833441833
# 215. CF_shidai_N2_ratio: 0.001090825734227325
# 216. CF_mushiro_N3_total: 0.001089267926348592
# 217. CF_keshitenai_N3_total: 0.0010769968016819324
# 218. CF_shikamo_N2_ratio: 0.001071421424282775
# 219. CF_ppoi_N3_ratio: 0.0010501584144656515
# 220. CF_moshikashitara_N3_ratio: 0.0010501139844399981
# 221. CF_tsumoride_N3_ratio: 0.0010336507219335955
# 222. CF_nimokakawarazu_N2_ratio: 0.0010030469140075997
# 223. CF_taradou_N4_total: 0.0009855738283698775
# 224. CF_monono_N2_ratio: 0.0009744211897356785
# 225. CF_soretomo_N3_ratio: 0.0009733043723521715
# 226. CF_saserareru_N4_total: 0.0009725911496241184
# 227. CF_hatashite_N2_total: 0.0009688138486576007
# 228. CF_kanousei_N1_ratio: 0.0009681270001330537
# 229. CF_saserareru_N4_ratio: 0.0009639294141496074
# 230. CF_kiru_N3_total: 0.0009408222410942906
# 231. CF_nao_N2_ratio: 0.0009176805887442089
# 232. CF_keshitenai_N3_ratio: 0.0009056081687095323
# 233. CF_kirenai_N3_total: 0.0008753602850686978
# 234. CF_kiru_N3_ratio: 0.0008638917067826693
# 235. CF_mushiro_N3_ratio: 0.0008571104680441968
# 236. CF_enai_N2_total: 0.0008558107146890593
# 237. CF_kotohanai_N4_total: 0.0008478441016364012
# 238. CF_sorenishitemo_N2_ratio: 0.0008460370687098644
# 239. CF_nisuginai_N2_total: 0.0008446453676967038
# 240. CF_tohakagiranai_N3_total: 0.0008184942409177356
# 241. CF_tohakagiranai_N3_ratio: 0.0007707822568709215
# 242. CF_taradou_N4_ratio: 0.0007565716250906719
# 243. CF_kaigiri_N2_total: 0.0007530674905415286
# 244. CF_nikimatteiru_N2_total: 0.0007513351372145885
# 245. CF_tsutsu_N2_total: 0.0007457124577169014
# 246. CF_ijyouni_N2_total: 0.0007270650681369822
# 247. CF_fuuni_N2_ratio: 0.0007058327610669556
# 248. CF_hatashite_N2_ratio: 0.000705542743617698
# 249. CF_tohaie_N1_total: 0.000704648225099343
# 250. CF_toiumonoda_N2_total: 0.0006989007277277468
# 251. CF_tsutsu_N2_ratio: 0.000685959537234707
# 252. CF_chigainai_N3_ratio: 0.0006817603277855625
# 253. CF_nikagitte_N2_total: 0.0006669697233153786
# 254. CF_kirenai_N3_ratio: 0.0006558095368296702
# 255. CF_kaigiri_N2_ratio: 0.0006518822554836469
# 256. CF_nikagitte_N2_ratio: 0.0006487928614892885
# 257. CF_chigainai_N3_total: 0.0006375362362577348
# 258. CF_toiumonoda_N2_ratio: 0.0006164630481363379
# 259. CF_onegau_N2_total: 0.0006101470155638342
# 260. CF_nisuginai_N2_ratio: 0.0006077628647055916
# 261. CF_tohaie_N1_ratio: 0.0006059098804795977
# 262. CF_ippouda_N3_total: 0.000604513525312873
# 263. CF_katsute_N1_total: 0.0005908132224786377
# 264. CF_kotohanai_N4_ratio: 0.0005758913772332127
# 265. CF_tetamaranai_N2_total: 0.0005739344602399103
# 266. CF_nikimatteiru_N2_ratio: 0.000566693775629355
# 267. CF_fuuni_N2_total: 0.0005649881535649279
# 268. CF_tetamaranai_N2_ratio: 0.0005613839995765924
# 269. CF_ijyouni_N2_ratio: 0.0005602593271841228
# 270. CF_katsute_N1_ratio: 0.0005590481766424869
# 271. CF_dounimonai_N1_total: 0.0005414743762486794
# 272. CF_onegau_N2_ratio: 0.000525881278484178
# 273. CF_nikagirazu_N2_total: 0.0004972078835018233
# 274. CF_nikagirazu_N2_ratio: 0.0004962407824107809
# 275. CF_ippouda_N3_ratio: 0.00048588636190589646
# 276. CF_toha_N1_total: 0.0004694231623393913
# 277. CF_dounimonai_N1_ratio: 0.0004630874658861703
# 278. CF_enai_N2_ratio: 0.0004393502071069421
# 279. CF_marude_N3_ratio: 0.000419368559312054
# 280. CF_toha_N1_ratio: 0.0004079768719380611
# 281. CF_gimi_N3_ratio: 0.00040702202599213677
# 282. CF_moshikuha_N1_total: 0.0003992019108395245
# 283. CF_gimi_N3_total: 0.00038598950815595025
# 284. CF_temiseru_N1_total: 0.000361906828233996
# 285. CF_marude_N3_total: 0.0003611505559293825
# 286. CF_temiseru_N1_ratio: 0.0003602813511457523
# 287. CF_moshikuha_N1_ratio: 0.0003388280188589048
# 288. CF_ppanashi_N3_ratio: 0.0003172201279041198
# 289. CF_ppanashi_N3_total: 0.0003137665898581853
# 290. CF_nimotodzuite_N2_ratio: 0.0002751007585904763
# 291. CF_nimotodzuite_N2_total: 0.0002747103621821231
# 292. CF_nikotaete_N2_ratio: 0.00027137468473575953
# 293. CF_nikotaete_N2_total: 0.0002704404854291103
# 294. CF_toiu_N1_ratio: 0.0002678374910962844
# 295. CF_toiu_N1_total: 0.0002675135332669348
# 296. CF_kashira_N4_total: 0.000266064902284136
# 297. CF_kashira_N4_ratio: 0.00026596176887535417
# 298. CF_karashite_N2_ratio: 0.00026165502246781614
# 299. CF_karashite_N2_total: 0.0002598591868499946
# 300. CF_nikaigiru_N2_ratio: 0.0002591113841855361
# 301. CF_nikaigiru_N2_total: 0.0002586569263445491
# 302. CF_deshikanai_N2_ratio: 0.0002433549618577657
# 303. CF_deshikanai_N2_total: 0.00024294803731344402
# 304. CF_nebanaranai_N2_ratio: 0.00024206336055873892
# 305. CF_toiuyori_N3_ratio: 0.00024170934163973332
# 306. CF_toiuyori_N3_total: 0.0002411351159135006
# 307. CF_nebanaranai_N2_total: 0.00024023401586116368
# 308. CF_tehairarenai_N2_total: 0.00023102808610383731
# 309. CF_tehairarenai_N2_ratio: 0.0002309394767155968
# 310. CF_nikakawarazu_N2_total: 0.00022828347752804485
# 311. CF_nikakawarazu_N2_ratio: 0.00022591236659481076
# 312. CF_naikotohanai_N3_total: 0.00022487093785390506
# 313. CF_naikotohanai_N3_ratio: 0.00022470712063232874
# 314. CF_kaigaru_N2_total: 0.00022335253609273882
# 315. CF_younakigasuru_N3_total: 0.0002226382454272901
# 316. CF_younakigasuru_N3_ratio: 0.00022228669369858851
# 317. CF_kaigaru_N2_ratio: 0.00022214059091951526
# 318. CF_tsuideni_N3_ratio: 0.00022083534263181624
# 319. CF_tsuideni_N3_total: 0.00021954585826769763
# 320. CF_teshikarubeki_N1_total: 0.00021897341327844344
# 321. CF_teshikarubeki_N1_ratio: 0.0002186929715002653
# 322. CF_bayokatta_N3_total: 0.00021026215703990792
# 323. CF_bayokatta_N3_ratio: 0.0002097725266453704
# 324. CF_ikanaru_N1_ratio: 0.00019491160119107555
# 325. CF_ikanaru_N1_total: 0.00019436754320495395
# 326. CF_aete_N1_total: 0.0
# 327. CF_aete_N1_ratio: 0.0
# 328. CF_yagate_N2_total: 0.0
# 329. CF_yagate_N2_ratio: 0.0
# 330. CF_mokamawazu_N2_total: 0.0
# 331. CF_mokamawazu_N2_ratio: 0.0
# 332. CF_amarini_N3_total: 0.0
# 333. CF_amarini_N3_ratio: 0.0
# 334. CF_bakoso_N1_total: 0.0
# 335. CF_bakoso_N1_ratio: 0.0
# 336. CF_ikoukei_N4_total: 0.0
# 337. CF_ikoukei_N4_ratio: 0.0
# 338. CF_hougamashi_N1_total: 0.0
# 339. CF_hougamashi_N1_ratio: 0.0
# 340. CF_annojyou_N1_total: 0.0
# 341. CF_annojyou_N1_ratio: 0.0
# 342. CF_tetouzenda_N2_total: 0.0
# 343. CF_tetouzenda_N2_ratio: 0.0
# 344. CF_karasuruto_N2_total: 0.0
# 345. CF_karasuruto_N2_ratio: 0.0
# 346. CF_yorihokanai_N2_total: 0.0
# 347. CF_yorihokanai_N2_ratio: 0.0
# 348. CF_kirigani_N1_total: 0.0
# 349. CF_kirigani_N1_ratio: 0.0
# 350. CF_deshouganai_N3_total: 0.0
# 351. CF_deshouganai_N3_ratio: 0.0
# 352. CF_karaiuto_N2_total: 0.0
# 353. CF_karaiuto_N2_ratio: 0.0
# 354. CF_katoomottara_N2_total: 0.0
# 355. CF_katoomottara_N2_ratio: 0.0
# 356. CF_kuseni_N3_total: 0.0
# 357. CF_kuseni_N3_ratio: 0.0
# 358. CF_gatai_N3_total: 0.0
# 359. CF_gatai_N3_ratio: 0.0
# 360. CF_arakajime_N1_total: 0.0
# 361. CF_arakajime_N1_ratio: 0.0
# 362. CF_naidehairarenai_N2_total: 0.0
# 363. CF_naidehairarenai_N2_ratio: 0.0
# 364. CF_kiraigaaru_N1_total: 0.0
# 365. CF_kiraigaaru_N1_ratio: 0.0

# %% [markdown]
# # --- 5 Fold Cross Validation 2回目 ---

# %%
#load data

file_path = os.path.join(os.getcwd(), 'training_data.csv')

#file_path = 'Users/megu/Documents/Tübingen Universität/Thesis/FeatureExtractor/src/training_data.csv'

df = pd.read_csv(file_path, index_col=0)

df = pd.read_csv(file_path, index_col=0)

#remove participant and text columns
df = df.drop(columns=['participant', 'text_name','JCATscore', 'loc', 'lang', 'age', 'gender']) # remove identifiers.

#remove native speaker rows
df=df[df['JLPT'] != 'NS']

#replace empty fields with 0
df=df.fillna(0)

#ensure categorical variables are recognized as such
categorical_columns = ['JLPT']

for col in categorical_columns:
    df[col] = df[col].astype('category')


X = df.drop(columns=['JLPT']) # feature columns (everything but JLPT column)
y = df['JLPT'].astype(str)

features_names = X.columns.tolist() 

# set the splits
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Set up cross validation
all_true=[]
all_predictions = []
all_indices = []
pre_counts_total = Counter()
post_counts_total= Counter()

for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
  print(f"\n Fold: {fold}")

  # split data
  x_train, x_test = X.iloc[train_index], X.iloc[test_index]
  y_train, y_test = y.iloc[train_index], y.iloc[test_index]
  pre_counts_total.update(y_train.value_counts().to_dict()) # update counts pre-sampling

  #Oversample within the training set
  ros = RandomOverSampler(random_state=42)
  x_train_resampled, y_train_resampled = ros.fit_resample(x_train, y_train)

  #convert resampled target to regular series
  y_train_resampled = pd.Series(y_train_resampled).astype(str)
  post_counts_total.update(y_train_resampled.value_counts().to_dict()) # update counts post-sampling

  #Train EBM
  ebm_fold = ExplainableBoostingClassifier(
      interactions=0, # no interactions
      random_state=42,
      n_jobs=1,
      )
  
  ebm_fold.fit(x_train_resampled, y_train_resampled)

  #Predict and evaluate
  y_pred = ebm_fold.predict(x_test)

  all_true.append(y_test)
  all_predictions.append(y_pred)
  all_indices.append(x_test.index)



  print(classification_report(y_test,y_pred))


print('finished training')
print('\n')
print('Total JLPT distribution BEFORE oversampling (across all folds)')
print('\n')
print(dict(pre_counts_total))
print('\n')
print('Total JLPT distribution AFTER oversampling (across all folds)')
print('n')
print(dict(post_counts_total))
######################################################
#  Model performace evaluation
######################################################
# Aggregate OOF results
y_true_all = pd.concat(all_true)
y_pred_all = np.concatenate(all_predictions)
indices_all = np.concatenate(all_indices)

# sort by the original order
order = np.argsort(indices_all)
y_true_all = y_true_all.iloc[order]
y_pred_all = y_pred_all[order]


JLPT_levels= ['N5','N4','N3','N2','N1']

cm= confusion_matrix(y_true_all, y_pred_all, labels=JLPT_levels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=JLPT_levels,
            yticklabels=JLPT_levels)
plt.xlabel('Predicted JLPT')
plt.ylabel('True JLPT')
plt.title('Confusion Matrix JLPT Level Prediction')
plt.show()


print('\n Overall Classification Report (All Folds Combined):')
print(classification_report(y_true_all, y_pred_all, labels=JLPT_levels))

####################################
# Per JLPT lvl Metrics
###################################

print("\n Per JLPT Level Metrics")
for level in JLPT_levels:
  mask = y_true_all == level
  y_true_subset = y_true_all[mask]
  y_pred_subset = y_pred_all[mask]
  accuracy = accuracy_score(y_true_subset, y_pred_subset)
  precision = precision_score(y_true_subset, y_pred_subset, average='weighted')
  recall = recall_score(y_true_subset, y_pred_subset, average='weighted')
  f1 = f1_score(y_true_subset, y_pred_subset, average='weighted')
  print(f"{level}: Accuracy = {accuracy} Precision = {precision} Recall = {recall} F1=f1")



######################################
# Final Model
######################################
ebm_final = ExplainableBoostingClassifier(
    interactions=0, # no interactions
    random_state=42,
    n_jobs=1,
    max_bins=256,
    max_leaves = 3,
    )
  
ebm_final.fit(X, y)

ebm_global = ebm_final.explain_global()
show(ebm_global)
# Out:
#  Fold: 0
#               precision    recall  f1-score   support
#
#           N1       0.22      0.24      0.23        45
#           N2       0.39      0.40      0.40       163
#           N3       0.42      0.41      0.41       269
#           N4       0.47      0.42      0.44       286
#           N5       0.47      0.55      0.50       147
#
#     accuracy                           0.43       910
#    macro avg       0.39      0.41      0.40       910
# weighted avg       0.43      0.43      0.43       910
#
#
#  Fold: 1
#               precision    recall  f1-score   support
#
#           N1       0.14      0.16      0.15        45
#           N2       0.32      0.37      0.34       163
#           N3       0.35      0.32      0.33       269
#           N4       0.41      0.38      0.39       286
#           N5       0.39      0.40      0.40       147
#
#     accuracy                           0.35       910
#    macro avg       0.32      0.33      0.32       910
# weighted avg       0.36      0.35      0.36       910
#
#
#  Fold: 2
#               precision    recall  f1-score   support
#
#           N1       0.21      0.24      0.22        45
#           N2       0.31      0.35      0.33       163
#           N3       0.36      0.34      0.35       268
#           N4       0.46      0.39      0.42       287
#           N5       0.46      0.54      0.50       147
#
#     accuracy                           0.39       910
#    macro avg       0.36      0.37      0.36       910
# weighted avg       0.39      0.39      0.39       910
#
#
#  Fold: 3
#               precision    recall  f1-score   support
#
#           N1       0.10      0.14      0.11        44
#           N2       0.32      0.35      0.33       164
#           N3       0.35      0.30      0.33       268
#           N4       0.40      0.40      0.40       286
#           N5       0.49      0.52      0.51       147
#
#     accuracy                           0.37       909
#    macro avg       0.33      0.34      0.34       909
# weighted avg       0.37      0.37      0.37       909
#
#
#  Fold: 4
#               precision    recall  f1-score   support
#
#           N1       0.13      0.16      0.14        45
#           N2       0.36      0.44      0.39       163
#           N3       0.39      0.33      0.36       268
#           N4       0.40      0.36      0.38       286
#           N5       0.45      0.52      0.48       147
#
#     accuracy                           0.38       909
#    macro avg       0.34      0.36      0.35       909
# weighted avg       0.38      0.38      0.38       909
#
# finished training
#
#
# Total JLPT distribution BEFORE oversampling (across all folds)
#
#
# {'N4': 5724, 'N3': 5368, 'N2': 3264, 'N5': 2940, 'N1': 896}
#
#
# Total JLPT distribution AFTER oversampling (across all folds)
# n
# {'N5': 5724, 'N3': 5724, 'N4': 5724, 'N2': 5724, 'N1': 5724}
#  Overall Classification Report (All Folds Combined):
#               precision    recall  f1-score   support
#
#           N5       0.45      0.51      0.48       735
#           N4       0.43      0.39      0.41      1431
#           N3       0.38      0.34      0.36      1342
#           N2       0.34      0.38      0.36       816
#           N1       0.15      0.19      0.17       224
#
#     accuracy                           0.38      4548
#    macro avg       0.35      0.36      0.35      4548
# weighted avg       0.39      0.38      0.38      4548
#
#
#  Per JLPT Level Metrics
# N5: Accuracy = 0.508843537414966 Precision = 1.0 Recall = 0.508843537414966 F1=f1
# N4: Accuracy = 0.389937106918239 Precision = 1.0 Recall = 0.389937106918239 F1=f1
# N3: Accuracy = 0.3405365126676602 Precision = 1.0 Recall = 0.3405365126676602 F1=f1
# N2: Accuracy = 0.38235294117647056 Precision = 1.0 Recall = 0.38235294117647056 F1=f1
# N1: Accuracy = 0.1875 Precision = 1.0 Recall = 0.1875 F1=f1
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# <!-- http://127.0.0.1:7001/6003161568/ -->
# <iframe src="http://127.0.0.1:7001/6003161568/" width=100% height=800 frameBorder="0"></iframe>

# %%
features_importance = ebm_global.data()

features_names = features_importance['names']
feature_importances = features_importance['scores']

sorted_features = sorted(zip(features_names, feature_importances), key=lambda x: x[1], reverse=True)

i=1
print(f'Top features rank')
for feature, importance in sorted_features:
    print(f"{i}. {feature}: {importance}")
    i+=1
# Out:
# Top features rank
# 1. Coordinate Clauses per sentence: 0.06150714808171355
# 2. Coordinate Clauses per clause: 0.06068824066234101
# 3. JLPT_Vocab_percent_N2: 0.05429376943212962
# 4. MHD: 0.0525333771807535
# 5. SCfreq: 0.050281970076648065
# 6. mci_5_surface: 0.04466900661502047
# 7. mci_10_surface: 0.043070862529754915
# 8. Avg Clause per Sent: 0.03623237502125395
# 9. JLPT_Vocab_percent_N4: 0.03583354052601373
# 10. LFP_OOV_percent: 0.03417828198993205
# 11. Avg Sent Length: 0.03219610903691309
# 12. CF_ukemi_N4_ratio: 0.03126223860303747
# 13. mci_10_inflection: 0.030292267341243982
# 14. MDD: 0.028865700725363912
# 15. JRMA_function_MATTR: 0.02859698967395621
# 16. JRMA_all_MATTR: 0.028462833468423064
# 17. adverb_density: 0.027861075987279264
# 18. adjective_density: 0.02784336896967561
# 19. JLPT_Vocab_N2: 0.02748448237074789
# 20. verb_density: 0.02559311571549184
# 21. LFP_3k_percent: 0.02545309887572069
# 22. JRMA_aux_chains: 0.025180621424552945
# 23. Subordinate Clauses per clause: 0.024741992832639205
# 24. LFP_4k_percent: 0.024021556095892963
# 25. LFP_9k_percent: 0.023467249015147632
# 26. JRMA_content_MTLD: 0.023109229221183386
# 27. LFP_6k_percent: 0.023014182979255164
# 28. JLPT_Vocab_percent_N5: 0.022783369517026454
# 29. CF_tekuru_N4_ratio: 0.022612454082800208
# 30. JLPT_Vocab_percent_N3: 0.02216269755750527
# 31. LFP_1k_percent: 0.021355355512677626
# 32. noun_density: 0.021214591872729633
# 33. JRMA_content_MATTR: 0.020953490174211113
# 34. JRMA_all_MTLD: 0.02054815715675381
# 35. JLPT_Vocab_percent_N1: 0.020473104412723174
# 36. MTLD_lemma: 0.020278996544812262
# 37. MTLD_surface: 0.019643636228142535
# 38. mci_5_inflection: 0.01903934312186635
# 39. LFP_7k_percent: 0.018185810630424838
# 40. CTTR: 0.017932091897093303
# 41. Avg Clause Length: 0.017571326083718843
# 42. JRMA_function_MTLD: 0.017160689868880072
# 43. Avg NP length: 0.01605753771687239
# 44. CF_saseru_N4_ratio: 0.015906397320456643
# 45. LFP_OOV_count: 0.01569149661814406
# 46. CF_toomou_N4_ratio: 0.015411918712733208
# 47. LFP_2k_percent: 0.015057894113281591
# 48. CCfreq: 0.014675743170880887
# 49. LFP_5k_percent: 0.014325431687252164
# 50. CF_saseru_N4_total: 0.013814928387995092
# 51. LFP_total_tokens: 0.013650962783384547
# 52. JLPT_Vocab_N4: 0.013611713114553323
# 53. CF_tsumori_N5_ratio: 0.013356655543628825
# 54. LFP_3k_count: 0.01332368180340223
# 55. CF_zuni_N3_total: 0.013134780351151475
# 56. JLPT_Vocab_N5: 0.013061788720780523
# 57. CF_tekuru_N4_total: 0.01297805734547482
# 58. CF_tara_N4_ratio: 0.012855572940248621
# 59. CF_tai_N5_ratio: 0.012707955900289112
# 60. CF_tsumori_N5_total: 0.012585400500429268
# 61. LFP_9k_count: 0.012547067517999083
# 62. LFP_6k_count: 0.012463705224541455
# 63. CF_total_N5: 0.012229446088818726
# 64. LFP_1k_count: 0.011938779497081138
# 65. Text Length: 0.011400873867257457
# 66. JLPT_Vocab_N1: 0.011372280578867333
# 67. Avg VP length: 0.011076144276636618
# 68. LFP_4k_count: 0.011041198053595366
# 69. CF_zuni_N3_ratio: 0.01102253156093988
# 70. CF_total_N4: 0.010927976369878115
# 71. LFP_2k_count: 0.010784466892699657
# 72. LFP_5k_count: 0.010783034964550567
# 73. Subordinate Clauses per Coordinate Clauses: 0.010259920818084219
# 74. LFP_7k_count: 0.010115360690594289
# 75. Subordinate Clauses per sentence: 0.010083370245237687
# 76. JLPT_Vocab_N3: 0.010039978994363197
# 77. CF_ukemi_N4_total: 0.009643191434162776
# 78. CF_hougaii_N5_ratio: 0.009351855103333405
# 79. CF_uchini_N3_total: 0.008734973219999952
# 80. CF_tara_N4_total: 0.008712062249776446
# 81. LFP_8k_percent: 0.008546019130204242
# 82. CF_hougaii_N5_total: 0.007878908174117594
# 83. CF_toomou_N4_total: 0.007583304759933407
# 84. CF_tai_N5_total: 0.007434154132003967
# 85. CF_total_N3: 0.007421550848488843
# 86. CF_toiu_N3_ratio: 0.007144851991801394
# 87. CF_uchini_N3_ratio: 0.007103463280239441
# 88. CF_total_N2: 0.006826881279695727
# 89. CF_temiru_N4_ratio: 0.006701900864286564
# 90. CF_tekudasai_N5_ratio: 0.006608760423982103
# 91. CF_burini_N2_total: 0.0065325792266560795
# 92. LFP_10k_percent: 0.006181343798358421
# 93. CF_ichiban_N5_ratio: 0.0059526351493430895
# 94. CF_temiru_N4_total: 0.005647607138270839
# 95. CF_tekudasai_N5_total: 0.005568736490901888
# 96. CF_youni_N4_ratio: 0.005163357192573189
# 97. CF_burini_N2_ratio: 0.00514291929455344
# 98. CF_gozaimasu_N4_total: 0.004871573414206807
# 99. CF_toiu_N3_total: 0.004804506169505024
# 100. CF_tari_N5_ratio: 0.004804249701802555
# 101. CF_okagede_N3_total: 0.004763069299760651
# 102. CF_amari_N3_ratio: 0.004742805507534316
# 103. LFP_8k_count: 0.004694146840787795
# 104. CF_tokoro_bakari_N4_ratio: 0.004656135148702695
# 105. CF_amari_N3_total: 0.004441057626139295
# 106. CF_dakedenaku_N3_total: 0.004307464872987078
# 107. CF_ichiban_N5_total: 0.004265109714336268
# 108. CF_youni_N4_total: 0.0042308123160708574
# 109. CF_tekureru_N4_ratio: 0.004162325175445361
# 110. CF_teitadakimasen_N4_ratio: 0.004068536761090168
# 111. CF_kotogaaru_N4_total: 0.004036823209102564
# 112. LFP_10k_count: 0.004035019418048702
# 113. CF_gozaimasu_N4_ratio: 0.003989883291995589
# 114. CF_ippou_N2_total: 0.0039831856073068665
# 115. CF_tekureru_N4_total: 0.0038962187237622688
# 116. CF_tokoro_bakari_N4_total: 0.003816286517344749
# 117. CF_bekida_N3_total: 0.003732798673163137
# 118. CF_teitadakimasen_N4_total: 0.003570451152335639
# 119. CF_sonoue_N2_total: 0.0035573534919641062
# 120. CF_tari_N5_total: 0.0034770518265418173
# 121. CF_kamoshirenai_N4_ratio: 0.003316177449171489
# 122. CF_tabini_N3_ratio: 0.0033114900307711515
# 123. CF_tashikani_N3_total: 0.003287783522846524
# 124. CF_ikurademo_N3_total: 0.003215455699269195
# 125. CF_okagede_N3_ratio: 0.003199336057628323
# 126. CF_tashikani_N3_ratio: 0.0031676013565272877
# 127. CF_ijyou_N4_total: 0.0031142761403261036
# 128. CF_sugiru_N5_total: 0.003057204355883612
# 129. CF_ijyou_N4_ratio: 0.0030497973281293127
# 130. CF_yasui_N4_total: 0.0030324599296294203
# 131. CF_kotogaaru_N4_ratio: 0.003003375209796457
# 132. CF_nasaru_N4_total: 0.002892512848756538
# 133. CF_ippou_N2_ratio: 0.0028619768498541493
# 134. CF_sugiru_N5_ratio: 0.0027673511875977766
# 135. CF_nakutehaikenai_N5_total: 0.002766114520234672
# 136. CF_eru_N2_total: 0.002736682695362342
# 137. CF_temorau_N4_total: 0.0027330221384195908
# 138. CF_teshimau_N4_total: 0.002714540125295236
# 139. CF_bekida_N3_ratio: 0.002708420931856811
# 140. CF_sonoue_N2_ratio: 0.002695552640111292
# 141. CF_hodonai_N3_total: 0.0026843555091285378
# 142. CF_yasui_N4_ratio: 0.0026672045681104886
# 143. CF_dakedo_N3_total: 0.0026505342456746056
# 144. CF_ikurademo_N3_ratio: 0.002648984890679722
# 145. CF_kurai_N5_ratio: 0.0026286979136932744
# 146. CF_kamoshirenai_N4_total: 0.0025811364585373343
# 147. CF_mottomo_N2_total: 0.002579710403750538
# 148. CF_seide_N3_ratio: 0.002531886284191959
# 149. CF_tabini_N3_total: 0.0025248703422983266
# 150. CF_total_N1: 0.002464244201469871
# 151. CF_hodo_N3_total: 0.002454138205748542
# 152. CF_hodo_N3_ratio: 0.0024476158704215124
# 153. CF_dakedo_N3_ratio: 0.002424912754910907
# 154. CF_nikuraberu_N3_total: 0.0024233793659922415
# 155. CF_nagaramo_N3_total: 0.0024112930805474287
# 156. CF_totomoni_N3_total: 0.002372448718432996
# 157. CF_kurai_N5_total: 0.0023671557657829008
# 158. CF_mitaini_N4_total: 0.0023620519747018253
# 159. CF_koso_N3_total: 0.002335253629904908
# 160. CF_yara_N2_total: 0.002294779182209821
# 161. CF_shikanai_N3_ratio: 0.002287484394887142
# 162. CF_sarani_N3_ratio: 0.0022334781552753786
# 163. CF_nasaru_N4_ratio: 0.002224837102972688
# 164. CF_dakedenaku_N3_ratio: 0.0022137204438746664
# 165. CF_temorau_N4_ratio: 0.0021961295006796156
# 166. CF_monodakara_N2_total: 0.0021879231565567724
# 167. CF_teshimau_N4_ratio: 0.0021684251758044507
# 168. CF_gasuru_N4_ratio: 0.0021247358615119677
# 169. CF_sae_N3_total: 0.0021053081914303544
# 170. CF_yori_N4_total: 0.0020867794818722122
# 171. CF_seide_N3_total: 0.0020745407586668417
# 172. CF_mitai_N4_total: 0.00202870634991366
# 173. CF_tsutsuaru_N2_total: 0.0019930371545293975
# 174. CF_nikui_N4_total: 0.0019905831225066044
# 175. CF_yori_N4_ratio: 0.00197352392267356
# 176. CF_mitai_N4_ratio: 0.001971727112826061
# 177. CF_shikanai_N4_total: 0.0019305968014067098
# 178. CF_eru_N2_ratio: 0.001918945135496485
# 179. CF_nakutehaikenai_N5_ratio: 0.0019032076441419582
# 180. CF_mottomo_N2_ratio: 0.0018306726952128543
# 181. CF_tsumari_N3_total: 0.0018302975118253888
# 182. CF_yara_N2_ratio: 0.0018098199118737044
# 183. CF_nikuraberu_N3_ratio: 0.0018068347117596141
# 184. CF_hodonai_N3_ratio: 0.0017771517825756445
# 185. CF_sae_N3_ratio: 0.0017370387334160482
# 186. CF_totomoni_N3_ratio: 0.001735861831441467
# 187. CF_nasai_N4_total: 0.0017125533136037644
# 188. CF_sarani_N3_total: 0.0016974239979911324
# 189. CF_gasuru_N4_total: 0.0016911365734792122
# 190. CF_shikanai_N3_total: 0.0016770396704625893
# 191. CF_ppoi_N3_total: 0.0016625963557773996
# 192. CF_monodakara_N2_ratio: 0.0016567342033667976
# 193. CF_nagaramo_N3_ratio: 0.0016366334570533853
# 194. CF_mitaini_N4_ratio: 0.0015784143050370809
# 195. CF_koso_N3_ratio: 0.0015502862487438303
# 196. CF_moshikashitara_N3_total: 0.0015342828585238775
# 197. CF_kanousei_N1_total: 0.0015229389054557667
# 198. CF_tsumari_N3_ratio: 0.0014564281201736684
# 199. CF_soretomo_N3_total: 0.001445163468946708
# 200. CF_shikanai_N4_ratio: 0.0014144037829799635
# 201. CF_nikui_N4_ratio: 0.0014089031217077135
# 202. CF_shidai_N2_total: 0.0014088034516525937
# 203. CF_nimokakawarazu_N2_total: 0.0013949520140053582
# 204. CF_tsumoride_N3_total: 0.0013357449690318312
# 205. CF_shikamo_N2_total: 0.0013050674480749442
# 206. CF_osoregaru_N2_total: 0.0012809142820578666
# 207. CF_monono_N2_total: 0.001262095361384917
# 208. CF_nasai_N4_ratio: 0.0012141733296100329
# 209. CF_tsutsuaru_N2_ratio: 0.0012091437686160718
# 210. CF_osoregaru_N2_ratio: 0.0011869666257495683
# 211. CF_tokangaerareru_N2_ratio: 0.0011783888107511518
# 212. CF_tokangaerareru_N2_total: 0.0011487145796328904
# 213. CF_sorenishitemo_N2_total: 0.0011437688076314562
# 214. CF_nao_N2_total: 0.0011410861833441833
# 215. CF_shidai_N2_ratio: 0.001090825734227325
# 216. CF_mushiro_N3_total: 0.001089267926348592
# 217. CF_keshitenai_N3_total: 0.0010769968016819324
# 218. CF_shikamo_N2_ratio: 0.001071421424282775
# 219. CF_ppoi_N3_ratio: 0.0010501584144656515
# 220. CF_moshikashitara_N3_ratio: 0.0010501139844399981
# 221. CF_tsumoride_N3_ratio: 0.0010336507219335955
# 222. CF_nimokakawarazu_N2_ratio: 0.0010030469140075997
# 223. CF_taradou_N4_total: 0.0009855738283698775
# 224. CF_monono_N2_ratio: 0.0009744211897356785
# 225. CF_soretomo_N3_ratio: 0.0009733043723521715
# 226. CF_saserareru_N4_total: 0.0009725911496241184
# 227. CF_hatashite_N2_total: 0.0009688138486576007
# 228. CF_kanousei_N1_ratio: 0.0009681270001330537
# 229. CF_saserareru_N4_ratio: 0.0009639294141496074
# 230. CF_kiru_N3_total: 0.0009408222410942906
# 231. CF_nao_N2_ratio: 0.0009176805887442089
# 232. CF_keshitenai_N3_ratio: 0.0009056081687095323
# 233. CF_kirenai_N3_total: 0.0008753602850686978
# 234. CF_kiru_N3_ratio: 0.0008638917067826693
# 235. CF_mushiro_N3_ratio: 0.0008571104680441968
# 236. CF_enai_N2_total: 0.0008558107146890593
# 237. CF_kotohanai_N4_total: 0.0008478441016364012
# 238. CF_sorenishitemo_N2_ratio: 0.0008460370687098644
# 239. CF_nisuginai_N2_total: 0.0008446453676967038
# 240. CF_tohakagiranai_N3_total: 0.0008184942409177356
# 241. CF_tohakagiranai_N3_ratio: 0.0007707822568709215
# 242. CF_taradou_N4_ratio: 0.0007565716250906719
# 243. CF_kaigiri_N2_total: 0.0007530674905415286
# 244. CF_nikimatteiru_N2_total: 0.0007513351372145885
# 245. CF_tsutsu_N2_total: 0.0007457124577169014
# 246. CF_ijyouni_N2_total: 0.0007270650681369822
# 247. CF_fuuni_N2_ratio: 0.0007058327610669556
# 248. CF_hatashite_N2_ratio: 0.000705542743617698
# 249. CF_tohaie_N1_total: 0.000704648225099343
# 250. CF_toiumonoda_N2_total: 0.0006989007277277468
# 251. CF_tsutsu_N2_ratio: 0.000685959537234707
# 252. CF_chigainai_N3_ratio: 0.0006817603277855625
# 253. CF_nikagitte_N2_total: 0.0006669697233153786
# 254. CF_kirenai_N3_ratio: 0.0006558095368296702
# 255. CF_kaigiri_N2_ratio: 0.0006518822554836469
# 256. CF_nikagitte_N2_ratio: 0.0006487928614892885
# 257. CF_chigainai_N3_total: 0.0006375362362577348
# 258. CF_toiumonoda_N2_ratio: 0.0006164630481363379
# 259. CF_onegau_N2_total: 0.0006101470155638342
# 260. CF_nisuginai_N2_ratio: 0.0006077628647055916
# 261. CF_tohaie_N1_ratio: 0.0006059098804795977
# 262. CF_ippouda_N3_total: 0.000604513525312873
# 263. CF_katsute_N1_total: 0.0005908132224786377
# 264. CF_kotohanai_N4_ratio: 0.0005758913772332127
# 265. CF_tetamaranai_N2_total: 0.0005739344602399103
# 266. CF_nikimatteiru_N2_ratio: 0.000566693775629355
# 267. CF_fuuni_N2_total: 0.0005649881535649279
# 268. CF_tetamaranai_N2_ratio: 0.0005613839995765924
# 269. CF_ijyouni_N2_ratio: 0.0005602593271841228
# 270. CF_katsute_N1_ratio: 0.0005590481766424869
# 271. CF_dounimonai_N1_total: 0.0005414743762486794
# 272. CF_onegau_N2_ratio: 0.000525881278484178
# 273. CF_nikagirazu_N2_total: 0.0004972078835018233
# 274. CF_nikagirazu_N2_ratio: 0.0004962407824107809
# 275. CF_ippouda_N3_ratio: 0.00048588636190589646
# 276. CF_toha_N1_total: 0.0004694231623393913
# 277. CF_dounimonai_N1_ratio: 0.0004630874658861703
# 278. CF_enai_N2_ratio: 0.0004393502071069421
# 279. CF_marude_N3_ratio: 0.000419368559312054
# 280. CF_toha_N1_ratio: 0.0004079768719380611
# 281. CF_gimi_N3_ratio: 0.00040702202599213677
# 282. CF_moshikuha_N1_total: 0.0003992019108395245
# 283. CF_gimi_N3_total: 0.00038598950815595025
# 284. CF_temiseru_N1_total: 0.000361906828233996
# 285. CF_marude_N3_total: 0.0003611505559293825
# 286. CF_temiseru_N1_ratio: 0.0003602813511457523
# 287. CF_moshikuha_N1_ratio: 0.0003388280188589048
# 288. CF_ppanashi_N3_ratio: 0.0003172201279041198
# 289. CF_ppanashi_N3_total: 0.0003137665898581853
# 290. CF_nimotodzuite_N2_ratio: 0.0002751007585904763
# 291. CF_nimotodzuite_N2_total: 0.0002747103621821231
# 292. CF_nikotaete_N2_ratio: 0.00027137468473575953
# 293. CF_nikotaete_N2_total: 0.0002704404854291103
# 294. CF_toiu_N1_ratio: 0.0002678374910962844
# 295. CF_toiu_N1_total: 0.0002675135332669348
# 296. CF_kashira_N4_total: 0.000266064902284136
# 297. CF_kashira_N4_ratio: 0.00026596176887535417
# 298. CF_karashite_N2_ratio: 0.00026165502246781614
# 299. CF_karashite_N2_total: 0.0002598591868499946
# 300. CF_nikaigiru_N2_ratio: 0.0002591113841855361
# 301. CF_nikaigiru_N2_total: 0.0002586569263445491
# 302. CF_deshikanai_N2_ratio: 0.0002433549618577657
# 303. CF_deshikanai_N2_total: 0.00024294803731344402
# 304. CF_nebanaranai_N2_ratio: 0.00024206336055873892
# 305. CF_toiuyori_N3_ratio: 0.00024170934163973332
# 306. CF_toiuyori_N3_total: 0.0002411351159135006
# 307. CF_nebanaranai_N2_total: 0.00024023401586116368
# 308. CF_tehairarenai_N2_total: 0.00023102808610383731
# 309. CF_tehairarenai_N2_ratio: 0.0002309394767155968
# 310. CF_nikakawarazu_N2_total: 0.00022828347752804485
# 311. CF_nikakawarazu_N2_ratio: 0.00022591236659481076
# 312. CF_naikotohanai_N3_total: 0.00022487093785390506
# 313. CF_naikotohanai_N3_ratio: 0.00022470712063232874
# 314. CF_kaigaru_N2_total: 0.00022335253609273882
# 315. CF_younakigasuru_N3_total: 0.0002226382454272901
# 316. CF_younakigasuru_N3_ratio: 0.00022228669369858851
# 317. CF_kaigaru_N2_ratio: 0.00022214059091951526
# 318. CF_tsuideni_N3_ratio: 0.00022083534263181624
# 319. CF_tsuideni_N3_total: 0.00021954585826769763
# 320. CF_teshikarubeki_N1_total: 0.00021897341327844344
# 321. CF_teshikarubeki_N1_ratio: 0.0002186929715002653
# 322. CF_bayokatta_N3_total: 0.00021026215703990792
# 323. CF_bayokatta_N3_ratio: 0.0002097725266453704
# 324. CF_ikanaru_N1_ratio: 0.00019491160119107555
# 325. CF_ikanaru_N1_total: 0.00019436754320495395
# 326. CF_aete_N1_total: 0.0
# 327. CF_aete_N1_ratio: 0.0
# 328. CF_yagate_N2_total: 0.0
# 329. CF_yagate_N2_ratio: 0.0
# 330. CF_mokamawazu_N2_total: 0.0
# 331. CF_mokamawazu_N2_ratio: 0.0
# 332. CF_amarini_N3_total: 0.0
# 333. CF_amarini_N3_ratio: 0.0
# 334. CF_bakoso_N1_total: 0.0
# 335. CF_bakoso_N1_ratio: 0.0
# 336. CF_ikoukei_N4_total: 0.0
# 337. CF_ikoukei_N4_ratio: 0.0
# 338. CF_hougamashi_N1_total: 0.0
# 339. CF_hougamashi_N1_ratio: 0.0
# 340. CF_annojyou_N1_total: 0.0
# 341. CF_annojyou_N1_ratio: 0.0
# 342. CF_tetouzenda_N2_total: 0.0
# 343. CF_tetouzenda_N2_ratio: 0.0
# 344. CF_karasuruto_N2_total: 0.0
# 345. CF_karasuruto_N2_ratio: 0.0
# 346. CF_yorihokanai_N2_total: 0.0
# 347. CF_yorihokanai_N2_ratio: 0.0
# 348. CF_kirigani_N1_total: 0.0
# 349. CF_kirigani_N1_ratio: 0.0
# 350. CF_deshouganai_N3_total: 0.0
# 351. CF_deshouganai_N3_ratio: 0.0
# 352. CF_karaiuto_N2_total: 0.0
# 353. CF_karaiuto_N2_ratio: 0.0
# 354. CF_katoomottara_N2_total: 0.0
# 355. CF_katoomottara_N2_ratio: 0.0
# 356. CF_kuseni_N3_total: 0.0
# 357. CF_kuseni_N3_ratio: 0.0
# 358. CF_gatai_N3_total: 0.0
# 359. CF_gatai_N3_ratio: 0.0
# 360. CF_arakajime_N1_total: 0.0
# 361. CF_arakajime_N1_ratio: 0.0
# 362. CF_naidehairarenai_N2_total: 0.0
# 363. CF_naidehairarenai_N2_ratio: 0.0
# 364. CF_kiraigaaru_N1_total: 0.0
# 365. CF_kiraigaaru_N1_ratio: 0.0
